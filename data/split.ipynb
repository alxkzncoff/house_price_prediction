# %% [markdown]
# # IMPORT

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # DATA

# %%
data = pd.read_csv('domofond.csv') # данные собраны 25.02.2021

# %%
data.head(10)
# Out:
#                                                 page  \
# 0  https://www.domofond.ru/1-komnatnaya-kvartira-...
# 1  https://www.domofond.ru/3-komnatnaya-kvartira-...
# 2  https://www.domofond.ru/kvartira-na-prodazhu-s...
# 3  https://www.domofond.ru/kvartira-na-prodazhu-s...
# 4  https://www.domofond.ru/3-komnatnaya-kvartira-...
# 5  https://www.domofond.ru/kvartira-na-prodazhu-s...
# 6  https://www.domofond.ru/4-komnatnaya-kvartira-...
# 7  https://www.domofond.ru/3-komnatnaya-kvartira-...
# 8  https://www.domofond.ru/kvartira-na-prodazhu-s...
# 9  https://www.domofond.ru/kvartira-na-prodazhu-s...
#
#                                          description              flat_type  \
# 0  Продаётся Однокомнатная квартира в новом доме ...  <span>Квартира</span>
# 1  Продается трёхкомнатная просторная квартира с ...  <span>Квартира</span>
# 2  Студия в историческом центре города, 2 минуты ...  <span>Квартира</span>
# 3  В ЖК Солнечный город, в доме 2018 гп продается...  <span>Квартира</span>
# 4  Продаётся Трёхкомнатная квартира в новом доме ...  <span>Квартира</span>
# 5  ДОМ СДАН! Продается квартира-студия  по догово...  <span>Квартира</span>
# 6  Предлагается к продаже большая 4 к.кв. общей п...  <span>Квартира</span>
# 7  Скидка 1% за покупку квартиры с использованием...  <span>Квартира</span>
# 8  Арт. 45617618 Продаётся светлая и уютная кварт...  <span>Квартира</span>
# 9  Уникальная квартира! Малоэтажный корпус!,дом г...  <span>Квартира</span>
#
#                 object_type                rooms              floors  \
# 0  <span>Новостройка</span>       <span>1</span>  <span>13/24</span>
# 1    <span>Вторичная</span>       <span>3</span>    <span>9/9</span>
# 2    <span>Вторичная</span>  <span>Студия</span>    <span>2/7</span>
# 3    <span>Вторичная</span>  <span>Студия</span>   <span>5/12</span>
# 4  <span>Новостройка</span>       <span>3</span>    <span>6/7</span>
# 5    <span>Вторичная</span>  <span>Студия</span>  <span>22/25</span>
# 6    <span>Вторичная</span>       <span>4</span>   <span>5/23</span>
# 7    <span>Вторичная</span>       <span>3</span>  <span>25/26</span>
# 8    <span>Вторичная</span>  <span>Студия</span>  <span>19/24</span>
# 9    <span>Вторичная</span>  <span>Студия</span>   <span>5/12</span>
#
#                   square        kitchen_square           live_square  \
# 0   <span>35.8 м²</span>  <span>10.2 м²</span>  <span>15.6 м²</span>
# 1   <span>70.3 м²</span>   <span>8.4 м²</span>    <span>45 м²</span>
# 2   <span>17.2 м²</span>         <span></span>         <span></span>
# 3   <span>23.5 м²</span>         <span></span>  <span>15.9 м²</span>
# 4    <span>108 м²</span>    <span>28 м²</span>  <span>45.6 м²</span>
# 5   <span>25.4 м²</span>         <span></span>    <span>13 м²</span>
# 6  <span>133.9 м²</span>  <span>19.2 м²</span>         <span></span>
# 7   <span>70.5 м²</span>    <span>10 м²</span>  <span>47.6 м²</span>
# 8   <span>22.4 м²</span>         <span></span>  <span>14.7 м²</span>
# 9   <span>26.5 м²</span>         <span></span>         <span></span>
#
#                        price  ... eco_rating clear_rating gkh_rating  \
# 0   <span>6 000 000 ₽</span>  ...        3,2          3,4        3,3
# 1   <span>8 000 000 ₽</span>  ...        3,4          3,2        2,9
# 2   <span>2 830 000 ₽</span>  ...        2,8          2,8        2,1
# 3   <span>3 650 000 ₽</span>  ...        3,4          3,2        2,9
# 4  <span>25 500 000 ₽</span>  ...        3,4          3,2        2,9
# 5   <span>4 100 000 ₽</span>  ...        3,2          3,4        3,3
# 6  <span>19 900 000 ₽</span>  ...        3,3          3,4        2,8
# 7  <span>10 550 000 ₽</span>  ...        3,3          3,0        3,0
# 8   <span>4 100 000 ₽</span>  ...        3,1          3,5        3,3
# 9   <span>2 999 000 ₽</span>  ...        3,4          3,2        2,9
#
#   neighbor_rating kids_rating sport_rest_rating shop_rating traffic_rating  \
# 0             3,9         3,9               3,7         4,5            3,3
# 1             3,7         3,8               3,5         4,3            3,2
# 2             3,4         3,4               3,1         3,3            2,6
# 3             3,7         3,8               3,5         4,3            3,2
# 4             3,7         3,8               3,5         4,3            3,2
# 5             3,9         3,9               3,7         4,5            3,3
# 6             3,8         3,7               3,5         4,1            3,3
# 7             3,6         4,1               3,7         4,4            3,1
# 8             3,8         3,9               3,8         4,5            2,9
# 9             3,7         3,8               3,5         4,3            3,2
#
#   secure_rating life_price_rating
# 0           3,8               2,8
# 1           3,4               2,5
# 2           3,4               2,4
# 3           3,4               2,5
# 4           3,4               2,5
# 5           3,8               2,8
# 6           3,8               2,6
# 7           3,0               2,5
# 8           3,7               2,7
# 9           3,4               2,5
#
# [10 rows x 28 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70228 entries, 0 to 70227
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   page               70228 non-null  object
#  1   description        70228 non-null  object
#  2   flat_type          70228 non-null  object
#  3   object_type        70228 non-null  object
#  4   rooms              70228 non-null  object
#  5   floors             70228 non-null  object
#  6   square             70228 non-null  object
#  7   kitchen_square     70228 non-null  object
#  8   live_square        70228 non-null  object
#  9   price              70228 non-null  object
#  10  price_per_m        70228 non-null  object
#  11  build_matireal     70228 non-null  object
#  12  public_date        70228 non-null  object
#  13  update_date        70228 non-null  object
#  14  catalog_id         70228 non-null  object
#  15  district_rating    70228 non-null  object
#  16  district           70228 non-null  object
#  17  underground        67003 non-null  object
#  18  eco_rating         70228 non-null  object
#  19  clear_rating       70228 non-null  object
#  20  gkh_rating         70228 non-null  object
#  21  neighbor_rating    70228 non-null  object
#  22  kids_rating        70228 non-null  object
#  23  sport_rest_rating  70228 non-null  object
#  24  shop_rating        70228 non-null  object
#  25  traffic_rating     70228 non-null  object
#  26  secure_rating      70228 non-null  object
#  27  life_price_rating  70228 non-null  object
# dtypes: object(28)
# memory usage: 15.0+ MB

# %% [markdown]
# # TRAIN TEST SPLIT

# %% [markdown]
# **Сразу же разделю данные на тренировочные и тестовые. Соотношение 70/30. Обрабатывать их буду отдельно друг от друга.**

# %%
train, test = train_test_split(data, test_size=0.3, shuffle=True)

# %%
train.head(5)
# Out:
#                                                     page  \
# 15599  https://www.domofond.ru/3-komnatnaya-kvartira-...
# 70000  https://www.domofond.ru/1-komnatnaya-kvartira-...
# 32335  https://www.domofond.ru/kvartira-na-prodazhu-s...
# 16488  https://www.domofond.ru/2-komnatnaya-kvartira-...
# 27365  https://www.domofond.ru/kvartira-na-prodazhu-s...
#
#                                              description  \
# 15599  Продается квартира 340, по адресу Малая Митроф...
# 70000  Продается просторная однокомнатная квартира с ...
# 32335  Организуем показы объектов в любом формате (он...
# 16488  ID 10299 - пожалуйста, сообщите этот номер мен...
# 27365  Организуем показы объектов в любом формате (он...
#
#                    flat_type               object_type                rooms  \
# 15599  <span>Квартира</span>  <span>Новостройка</span>       <span>3</span>
# 70000  <span>Квартира</span>    <span>Вторичная</span>       <span>1</span>
# 32335  <span>Квартира</span>  <span>Новостройка</span>  <span>Студия</span>
# 16488  <span>Квартира</span>    <span>Вторичная</span>       <span>2</span>
# 27365  <span>Квартира</span>  <span>Новостройка</span>  <span>Студия</span>
#
#                    floors                square        kitchen_square  \
# 15599   <span>2/19</span>  <span>98.8 м²</span>  <span>20.9 м²</span>
# 70000   <span>3/17</span>  <span>42.1 м²</span>    <span>12 м²</span>
# 32335  <span>16/20</span>  <span>22.1 м²</span>         <span></span>
# 16488  <span>22/25</span>  <span>56.9 м²</span>  <span>17.1 м²</span>
# 27365   <span>2/24</span>  <span>24.5 м²</span>         <span></span>
#
#                 live_square                      price  ... eco_rating  \
# 15599  <span>51.9 м²</span>  <span>15 138 577 ₽</span>  ...        3,6
# 70000  <span>16.5 м²</span>   <span>5 480 000 ₽</span>  ...        3,7
# 32335         <span></span>   <span>2 607 786 ₽</span>  ...        3,4
# 16488         <span></span>   <span>8 140 000 ₽</span>  ...        3,2
# 27365         <span></span>   <span>3 132 000 ₽</span>  ...        2,8
#
#       clear_rating gkh_rating neighbor_rating kids_rating sport_rest_rating  \
# 15599          3,5        3,3             3,8         4,0               3,9
# 70000          3,4        3,2             3,8         3,8               3,6
# 32335          3,2        2,9             3,7         3,8               3,5
# 16488          3,4        3,3             3,9         3,9               3,7
# 27365          2,6        2,3             3,2         3,9               2,4
#
#       shop_rating traffic_rating secure_rating life_price_rating
# 15599         4,5            3,5           3,8               2,8
# 70000         4,3            3,1           3,6               2,6
# 32335         4,3            3,2           3,4               2,5
# 16488         4,5            3,3           3,8               2,8
# 27365         3,5            2,6           2,9               1,8
#
# [5 rows x 28 columns]

# %%
test.head(5)
# Out:
#                                                     page  \
# 41402  https://www.domofond.ru/1-komnatnaya-kvartira-...
# 62961  https://www.domofond.ru/2-komnatnaya-kvartira-...
# 42274  https://www.domofond.ru/1-komnatnaya-kvartira-...
# 5305   https://www.domofond.ru/3-komnatnaya-kvartira-...
# 36424  https://www.domofond.ru/1-komnatnaya-kvartira-...
#
#                                              description  \
# 41402  Организуем показы объектов в любом формате (он...
# 62961  В прямой продаже просторная уютная двухкомнатн...
# 42274  Организуем показы объектов в любом формате (он...
# 5305   Продаётся квартира нашей бабушки. Дом 1975 год...
# 36424  Организуем показы объектов в любом формате (он...
#
#                    flat_type               object_type           rooms  \
# 41402  <span>Квартира</span>  <span>Новостройка</span>  <span>1</span>
# 62961  <span>Квартира</span>    <span>Вторичная</span>  <span>2</span>
# 42274  <span>Квартира</span>  <span>Новостройка</span>  <span>1</span>
# 5305   <span>Квартира</span>    <span>Вторичная</span>  <span>3</span>
# 36424  <span>Квартира</span>  <span>Новостройка</span>  <span>1</span>
#
#                    floors                square      kitchen_square  \
# 41402  <span>17/20</span>    <span>43 м²</span>       <span></span>
# 62961  <span>11/12</span>  <span>54.1 м²</span>  <span>10 м²</span>
# 42274  <span>12/12</span>  <span>47.3 м²</span>       <span></span>
# 5305     <span>4/9</span>    <span>59 м²</span>       <span></span>
# 36424   <span>2/13</span>  <span>50.6 м²</span>       <span></span>
#
#               live_square                      price  ... eco_rating  \
# 41402       <span></span>   <span>8 464 817 ₽</span>  ...        3,1
# 62961  <span>32 м²</span>   <span>7 200 000 ₽</span>  ...        3,4
# 42274       <span></span>  <span>10 651 500 ₽</span>  ...        3,1
# 5305        <span></span>   <span>6 500 000 ₽</span>  ...        3,1
# 36424       <span></span>   <span>7 447 000 ₽</span>  ...        3,1
#
#       clear_rating gkh_rating neighbor_rating kids_rating sport_rest_rating  \
# 41402          2,3        2,0             3,4         4,1               2,9
# 62961          3,2        2,9             3,7         3,8               3,5
# 42274          3,5        3,3             3,8         3,9               3,8
# 5305           3,4        3,1             3,7         3,6               3,5
# 36424          3,5        3,3             3,8         3,9               3,8
#
#       shop_rating traffic_rating secure_rating life_price_rating
# 41402         3,5            3,5           3,2               2,4
# 62961         4,3            3,2           3,4               2,5
# 42274         4,5            2,9           3,7               2,7
# 5305          4,4            3,0           3,6               2,8
# 36424         4,5            2,9           3,7               2,7
#
# [5 rows x 28 columns]

# %%
train.reset_index(drop=True, inplace=True)
test.reset_index(drop=True, inplace=True)

# %% [markdown]
# **Сразу же удалю html теги `<span>`, `</span>`.**

# %%
def remove_span(df):
    
    """Функция удаляет html теги из датасета."""
    
    temp_df = df.copy()  # Копируем dataframe, чтобы небыло ошибки SettingWithCopyWarning
    
    for column in temp_df.columns[2:-13]:
        temp_df[column] = temp_df[column].apply(lambda x: x.split('<span>')[1].split('</span>')[0])
        
    return temp_df

# %%
train = remove_span(train)
test = remove_span(test)

# %%
train.head(5)
# Out:
#                                                 page  \
# 0  https://www.domofond.ru/3-komnatnaya-kvartira-...
# 1  https://www.domofond.ru/1-komnatnaya-kvartira-...
# 2  https://www.domofond.ru/kvartira-na-prodazhu-s...
# 3  https://www.domofond.ru/2-komnatnaya-kvartira-...
# 4  https://www.domofond.ru/kvartira-na-prodazhu-s...
#
#                                          description flat_type  object_type  \
# 0  Продается квартира 340, по адресу Малая Митроф...  Квартира  Новостройка
# 1  Продается просторная однокомнатная квартира с ...  Квартира    Вторичная
# 2  Организуем показы объектов в любом формате (он...  Квартира  Новостройка
# 3  ID 10299 - пожалуйста, сообщите этот номер мен...  Квартира    Вторичная
# 4  Организуем показы объектов в любом формате (он...  Квартира  Новостройка
#
#     rooms floors   square kitchen_square live_square         price  ...  \
# 0       3   2/19  98.8 м²        20.9 м²     51.9 м²  15 138 577 ₽  ...
# 1       1   3/17  42.1 м²          12 м²     16.5 м²   5 480 000 ₽  ...
# 2  Студия  16/20  22.1 м²                              2 607 786 ₽  ...
# 3       2  22/25  56.9 м²        17.1 м²               8 140 000 ₽  ...
# 4  Студия   2/24  24.5 м²                              3 132 000 ₽  ...
#
#   eco_rating clear_rating gkh_rating neighbor_rating kids_rating  \
# 0        3,6          3,5        3,3             3,8         4,0
# 1        3,7          3,4        3,2             3,8         3,8
# 2        3,4          3,2        2,9             3,7         3,8
# 3        3,2          3,4        3,3             3,9         3,9
# 4        2,8          2,6        2,3             3,2         3,9
#
#   sport_rest_rating shop_rating traffic_rating secure_rating life_price_rating
# 0               3,9         4,5            3,5           3,8               2,8
# 1               3,6         4,3            3,1           3,6               2,6
# 2               3,5         4,3            3,2           3,4               2,5
# 3               3,7         4,5            3,3           3,8               2,8
# 4               2,4         3,5            2,6           2,9               1,8
#
# [5 rows x 28 columns]

# %%
test.head(5)
# Out:
#                                                 page  \
# 0  https://www.domofond.ru/1-komnatnaya-kvartira-...
# 1  https://www.domofond.ru/2-komnatnaya-kvartira-...
# 2  https://www.domofond.ru/1-komnatnaya-kvartira-...
# 3  https://www.domofond.ru/3-komnatnaya-kvartira-...
# 4  https://www.domofond.ru/1-komnatnaya-kvartira-...
#
#                                          description flat_type  object_type  \
# 0  Организуем показы объектов в любом формате (он...  Квартира  Новостройка
# 1  В прямой продаже просторная уютная двухкомнатн...  Квартира    Вторичная
# 2  Организуем показы объектов в любом формате (он...  Квартира  Новостройка
# 3  Продаётся квартира нашей бабушки. Дом 1975 год...  Квартира    Вторичная
# 4  Организуем показы объектов в любом формате (он...  Квартира  Новостройка
#
#   rooms floors   square kitchen_square live_square         price  ...  \
# 0     1  17/20    43 м²                              8 464 817 ₽  ...
# 1     2  11/12  54.1 м²          10 м²       32 м²   7 200 000 ₽  ...
# 2     1  12/12  47.3 м²                             10 651 500 ₽  ...
# 3     3    4/9    59 м²                              6 500 000 ₽  ...
# 4     1   2/13  50.6 м²                              7 447 000 ₽  ...
#
#   eco_rating clear_rating gkh_rating neighbor_rating kids_rating  \
# 0        3,1          2,3        2,0             3,4         4,1
# 1        3,4          3,2        2,9             3,7         3,8
# 2        3,1          3,5        3,3             3,8         3,9
# 3        3,1          3,4        3,1             3,7         3,6
# 4        3,1          3,5        3,3             3,8         3,9
#
#   sport_rest_rating shop_rating traffic_rating secure_rating life_price_rating
# 0               2,9         3,5            3,5           3,2               2,4
# 1               3,5         4,3            3,2           3,4               2,5
# 2               3,8         4,5            2,9           3,7               2,7
# 3               3,5         4,4            3,0           3,6               2,8
# 4               3,8         4,5            2,9           3,7               2,7
#
# [5 rows x 28 columns]

# %% [markdown]
# # EXPORT DATA

# %%
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)
